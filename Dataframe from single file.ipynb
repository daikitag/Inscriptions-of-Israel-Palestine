# %%
import pandas as pd
import xml.etree.ElementTree as ET
import urllib.request
dataf={'ID':['title','language','physical type','religion','Object Description','Object Description (Support)',
                 'Unit of Dimension','height','width','depth','condition','relief style','written column','written line',
                 'Unit of letter size','At least letter size','At most letter size','Oldest discovery year',
                  'Earliest discovery year','Region of discovery','City of discovery','Geography name',
                  'Geography feature','provenance','commentary']}


try:
        url = 'https://library.brown.edu/cds/projects/iip/view_xml/mger0007b/'
        response = urllib.request.urlopen(url).read()
        root = ET.fromstring(response)
        
        [title,ID,language,physical,religion,objec,support,unit,height,width,depth,condition,
                                 relief,column,line,unit_letter,small,large,old,early,region,city,geogname,
                                 geogfeature,provenance,commentary]=['','','','','','','','','','','','','','','','','','',
                                                                     '','','','','','','','']
        
        try:
            # title
            title=(root.find('{http://www.tei-c.org/ns/1.0}teiHeader')
           .find('{http://www.tei-c.org/ns/1.0}fileDesc')
           .find('{http://www.tei-c.org/ns/1.0}sourceDesc')
           .find('{http://www.tei-c.org/ns/1.0}msDesc')
           .find('{http://www.tei-c.org/ns/1.0}msContents')
           .find('{http://www.tei-c.org/ns/1.0}msItem')[0].text)
        except:
            pass
        
        ID=root.get('{http://www.w3.org/XML/1998/namespace}id')
        
        try:
            # language
            language=(root.find('{http://www.tei-c.org/ns/1.0}teiHeader')
       .find('{http://www.tei-c.org/ns/1.0}fileDesc')
       .find('{http://www.tei-c.org/ns/1.0}sourceDesc')
       .find('{http://www.tei-c.org/ns/1.0}msDesc')
       .find('{http://www.tei-c.org/ns/1.0}msContents')
       .find('{http://www.tei-c.org/ns/1.0}textLang').get('mainLang'))
            if language =='grc':
                   language="Greek"
            elif language =="arc":
                    language="Aramaic"
            elif language =="he":
                    language="Hebrew"
            elif language =="la":
                    language="Latin"
            else:
                    language=""
        except:
            pass
        
        try:
            # Physical Type
            physical=(root.find('{http://www.tei-c.org/ns/1.0}teiHeader')
                   .find('{http://www.tei-c.org/ns/1.0}fileDesc')
                   .find('{http://www.tei-c.org/ns/1.0}sourceDesc')
                   .find('{http://www.tei-c.org/ns/1.0}msDesc')
                   .find('{http://www.tei-c.org/ns/1.0}msContents')
                   .find('{http://www.tei-c.org/ns/1.0}msItem').get('class'))
            physical=physical.replace('#', '')
        except:
            pass
        
        try:
            # Religion
            religion=(root.find('{http://www.tei-c.org/ns/1.0}teiHeader')
                   .find('{http://www.tei-c.org/ns/1.0}fileDesc')
                   .find('{http://www.tei-c.org/ns/1.0}sourceDesc')
                   .find('{http://www.tei-c.org/ns/1.0}msDesc')
                   .find('{http://www.tei-c.org/ns/1.0}msContents')
                   .find('{http://www.tei-c.org/ns/1.0}msItem').get('ana'))
            religion=religion.replace('#', '')
        except:
            pass
        
        try:
            # Object Description
            objec=(root.find('{http://www.tei-c.org/ns/1.0}teiHeader')
                   .find('{http://www.tei-c.org/ns/1.0}fileDesc')
                   .find('{http://www.tei-c.org/ns/1.0}sourceDesc')
                   .find('{http://www.tei-c.org/ns/1.0}msDesc')
                   .find('{http://www.tei-c.org/ns/1.0}physDesc')
                   .find('{http://www.tei-c.org/ns/1.0}objectDesc').get('ana'))
            objec=objec.replace('#','')
        except:
            pass
        
        try:
            # Object Description (Support)
            support=(root.find('{http://www.tei-c.org/ns/1.0}teiHeader')
                   .find('{http://www.tei-c.org/ns/1.0}fileDesc')
                   .find('{http://www.tei-c.org/ns/1.0}sourceDesc')
                   .find('{http://www.tei-c.org/ns/1.0}msDesc')
                   .find('{http://www.tei-c.org/ns/1.0}physDesc')
                   .find('{http://www.tei-c.org/ns/1.0}objectDesc')
                     .find('{http://www.tei-c.org/ns/1.0}supportDesc').get('ana'))
            support=support.replace('#','')
        except:
            pass
        
        try:
            # Unit of Dimension
            unit=(root.find('{http://www.tei-c.org/ns/1.0}teiHeader')
                   .find('{http://www.tei-c.org/ns/1.0}fileDesc')
                   .find('{http://www.tei-c.org/ns/1.0}sourceDesc')
                   .find('{http://www.tei-c.org/ns/1.0}msDesc')
                   .find('{http://www.tei-c.org/ns/1.0}physDesc')
                   .find('{http://www.tei-c.org/ns/1.0}objectDesc')
                     .find('{http://www.tei-c.org/ns/1.0}supportDesc')
                  .find('{http://www.tei-c.org/ns/1.0}support')
                  .find('{http://www.tei-c.org/ns/1.0}dimensions').get('unit'))
        except:
                pass
        
        try:
            # Height
            height=(root.find('{http://www.tei-c.org/ns/1.0}teiHeader')
                   .find('{http://www.tei-c.org/ns/1.0}fileDesc')
                   .find('{http://www.tei-c.org/ns/1.0}sourceDesc')
                   .find('{http://www.tei-c.org/ns/1.0}msDesc')
                   .find('{http://www.tei-c.org/ns/1.0}physDesc')
                   .find('{http://www.tei-c.org/ns/1.0}objectDesc')
                     .find('{http://www.tei-c.org/ns/1.0}supportDesc')
                  .find('{http://www.tei-c.org/ns/1.0}support')
                  .find('{http://www.tei-c.org/ns/1.0}dimensions')
                  .find('{http://www.tei-c.org/ns/1.0}height').text)
        except:
            pass
        
        try:
            # Width
            width=(root.find('{http://www.tei-c.org/ns/1.0}teiHeader')
                   .find('{http://www.tei-c.org/ns/1.0}fileDesc')
                   .find('{http://www.tei-c.org/ns/1.0}sourceDesc')
                   .find('{http://www.tei-c.org/ns/1.0}msDesc')
                   .find('{http://www.tei-c.org/ns/1.0}physDesc')
                   .find('{http://www.tei-c.org/ns/1.0}objectDesc')
                     .find('{http://www.tei-c.org/ns/1.0}supportDesc')
                  .find('{http://www.tei-c.org/ns/1.0}support')
                  .find('{http://www.tei-c.org/ns/1.0}dimensions')
                  .find('{http://www.tei-c.org/ns/1.0}width').text)
        except:
            pass
        
        try:
            # Depth
            depth=(root.find('{http://www.tei-c.org/ns/1.0}teiHeader')
                   .find('{http://www.tei-c.org/ns/1.0}fileDesc')
                   .find('{http://www.tei-c.org/ns/1.0}sourceDesc')
                   .find('{http://www.tei-c.org/ns/1.0}msDesc')
                   .find('{http://www.tei-c.org/ns/1.0}physDesc')
                   .find('{http://www.tei-c.org/ns/1.0}objectDesc')
                     .find('{http://www.tei-c.org/ns/1.0}supportDesc')
                  .find('{http://www.tei-c.org/ns/1.0}support')
                  .find('{http://www.tei-c.org/ns/1.0}dimensions')
                  .find('{http://www.tei-c.org/ns/1.0}depth').text)
        except:
            pass
        
        try:
            # Condition
            condition=(root.find('{http://www.tei-c.org/ns/1.0}teiHeader')
                   .find('{http://www.tei-c.org/ns/1.0}fileDesc')
                   .find('{http://www.tei-c.org/ns/1.0}sourceDesc')
                   .find('{http://www.tei-c.org/ns/1.0}msDesc')
                   .find('{http://www.tei-c.org/ns/1.0}physDesc')
                   .find('{http://www.tei-c.org/ns/1.0}objectDesc')
                     .find('{http://www.tei-c.org/ns/1.0}supportDesc')
                  .find('{http://www.tei-c.org/ns/1.0}condition').get('ana'))
            condition=condition.replace('#','')
        except:
            pass
        
        try:
            # Relief Style
            relief=(root.find('{http://www.tei-c.org/ns/1.0}teiHeader')
                   .find('{http://www.tei-c.org/ns/1.0}fileDesc')
                   .find('{http://www.tei-c.org/ns/1.0}sourceDesc')
                   .find('{http://www.tei-c.org/ns/1.0}msDesc')
                   .find('{http://www.tei-c.org/ns/1.0}physDesc')
                   .find('{http://www.tei-c.org/ns/1.0}handDesc')
                     .find('{http://www.tei-c.org/ns/1.0}handNote').get('ana'))
            relief=relief.replace('#','')
        except:
            pass
        
        try:
            # Written Column
            column=(root.find('{http://www.tei-c.org/ns/1.0}teiHeader')
                   .find('{http://www.tei-c.org/ns/1.0}fileDesc')
                   .find('{http://www.tei-c.org/ns/1.0}sourceDesc')
                   .find('{http://www.tei-c.org/ns/1.0}msDesc')
                   .find('{http://www.tei-c.org/ns/1.0}physDesc')
                   .find('{http://www.tei-c.org/ns/1.0}objectDesc')
                     .find('{http://www.tei-c.org/ns/1.0}layoutDesc')
                  .find('{http://www.tei-c.org/ns/1.0}layout').get('columns'))
        except:
            pass
        
        try:
            # Written Lines
            line=(root.find('{http://www.tei-c.org/ns/1.0}teiHeader')
                   .find('{http://www.tei-c.org/ns/1.0}fileDesc')
                   .find('{http://www.tei-c.org/ns/1.0}sourceDesc')
                   .find('{http://www.tei-c.org/ns/1.0}msDesc')
                   .find('{http://www.tei-c.org/ns/1.0}physDesc')
                   .find('{http://www.tei-c.org/ns/1.0}objectDesc')
                     .find('{http://www.tei-c.org/ns/1.0}layoutDesc')
                  .find('{http://www.tei-c.org/ns/1.0}layout').get('writtenLines'))
        except:
            pass
        
        try:
            # Unit of letter size
            unit_letter=(root.find('{http://www.tei-c.org/ns/1.0}teiHeader')
                   .find('{http://www.tei-c.org/ns/1.0}fileDesc')
                   .find('{http://www.tei-c.org/ns/1.0}sourceDesc')
                   .find('{http://www.tei-c.org/ns/1.0}msDesc')
                   .find('{http://www.tei-c.org/ns/1.0}physDesc')
                   .find('{http://www.tei-c.org/ns/1.0}handDesc')
                     .find('{http://www.tei-c.org/ns/1.0}handNote')
                         .find('{http://www.tei-c.org/ns/1.0}dimensions').get('unit'))
        except:
            pass
        
        try:
            # At least letter size
            small=(root.find('{http://www.tei-c.org/ns/1.0}teiHeader')
                   .find('{http://www.tei-c.org/ns/1.0}fileDesc')
                   .find('{http://www.tei-c.org/ns/1.0}sourceDesc')
                   .find('{http://www.tei-c.org/ns/1.0}msDesc')
                   .find('{http://www.tei-c.org/ns/1.0}physDesc')
                   .find('{http://www.tei-c.org/ns/1.0}handDesc')
                     .find('{http://www.tei-c.org/ns/1.0}handNote')
                         .find('{http://www.tei-c.org/ns/1.0}dimensions').get('atLeast'))
        except:
            pass
        
        try:
            # At most letter size
            large=(root.find('{http://www.tei-c.org/ns/1.0}teiHeader')
                   .find('{http://www.tei-c.org/ns/1.0}fileDesc')
                   .find('{http://www.tei-c.org/ns/1.0}sourceDesc')
                   .find('{http://www.tei-c.org/ns/1.0}msDesc')
                   .find('{http://www.tei-c.org/ns/1.0}physDesc')
                   .find('{http://www.tei-c.org/ns/1.0}handDesc')
                     .find('{http://www.tei-c.org/ns/1.0}handNote')
                         .find('{http://www.tei-c.org/ns/1.0}dimensions').get('atMost'))
        except:
            pass

        try:
            # when letter size is specified
            if large is None:
                large=(root.find('{http://www.tei-c.org/ns/1.0}teiHeader')
                   .find('{http://www.tei-c.org/ns/1.0}fileDesc')
                   .find('{http://www.tei-c.org/ns/1.0}sourceDesc')
                   .find('{http://www.tei-c.org/ns/1.0}msDesc')
                   .find('{http://www.tei-c.org/ns/1.0}physDesc')
                   .find('{http://www.tei-c.org/ns/1.0}handDesc')
                     .find('{http://www.tei-c.org/ns/1.0}handNote')
                         .find('{http://www.tei-c.org/ns/1.0}dimensions').get('quantity'))
                small=large
        except:
            pass
        
        try:
            # Oldest discovery year
            old=(root.find('{http://www.tei-c.org/ns/1.0}teiHeader')
                   .find('{http://www.tei-c.org/ns/1.0}fileDesc')
                   .find('{http://www.tei-c.org/ns/1.0}sourceDesc')
                   .find('{http://www.tei-c.org/ns/1.0}msDesc')
                   .find('{http://www.tei-c.org/ns/1.0}history')
                   .find('{http://www.tei-c.org/ns/1.0}origin')
                     .find('{http://www.tei-c.org/ns/1.0}date').get('notBefore'))
        except:
            pass
        
        try:
            # Earliest discovery year
            early=(root.find('{http://www.tei-c.org/ns/1.0}teiHeader')
                   .find('{http://www.tei-c.org/ns/1.0}fileDesc')
                   .find('{http://www.tei-c.org/ns/1.0}sourceDesc')
                   .find('{http://www.tei-c.org/ns/1.0}msDesc')
                   .find('{http://www.tei-c.org/ns/1.0}history')
                   .find('{http://www.tei-c.org/ns/1.0}origin')
                     .find('{http://www.tei-c.org/ns/1.0}date').get('notAfter'))
        except:
            pass
        
        try:
            # Region of discovery
            region=(root.find('{http://www.tei-c.org/ns/1.0}teiHeader')
                   .find('{http://www.tei-c.org/ns/1.0}fileDesc')
                   .find('{http://www.tei-c.org/ns/1.0}sourceDesc')
                   .find('{http://www.tei-c.org/ns/1.0}msDesc')
                   .find('{http://www.tei-c.org/ns/1.0}history')
                   .find('{http://www.tei-c.org/ns/1.0}origin')
                     .find('{http://www.tei-c.org/ns/1.0}placeName')
                    .find('{http://www.tei-c.org/ns/1.0}region').text)
        except:
            pass
        
        try:
            # City of discovery
            city=(root.find('{http://www.tei-c.org/ns/1.0}teiHeader')
                   .find('{http://www.tei-c.org/ns/1.0}fileDesc')
                   .find('{http://www.tei-c.org/ns/1.0}sourceDesc')
                   .find('{http://www.tei-c.org/ns/1.0}msDesc')
                   .find('{http://www.tei-c.org/ns/1.0}history')
                   .find('{http://www.tei-c.org/ns/1.0}origin')
                     .find('{http://www.tei-c.org/ns/1.0}placeName')
                    .find('{http://www.tei-c.org/ns/1.0}settlement').text)
        except:
            pass
        
        try:
            # Geography name
            geogname=(root.find('{http://www.tei-c.org/ns/1.0}teiHeader')
                   .find('{http://www.tei-c.org/ns/1.0}fileDesc')
                   .find('{http://www.tei-c.org/ns/1.0}sourceDesc')
                   .find('{http://www.tei-c.org/ns/1.0}msDesc')
                   .find('{http://www.tei-c.org/ns/1.0}history')
                   .find('{http://www.tei-c.org/ns/1.0}origin')
                     .find('{http://www.tei-c.org/ns/1.0}placeName')
                    .find('{http://www.tei-c.org/ns/1.0}geogName').text)
        except:
            pass
        
        try:
            # Geography feature
            geogfeature=(root.find('{http://www.tei-c.org/ns/1.0}teiHeader')
                   .find('{http://www.tei-c.org/ns/1.0}fileDesc')
                   .find('{http://www.tei-c.org/ns/1.0}sourceDesc')
                   .find('{http://www.tei-c.org/ns/1.0}msDesc')
                   .find('{http://www.tei-c.org/ns/1.0}history')
                   .find('{http://www.tei-c.org/ns/1.0}origin')
                     .find('{http://www.tei-c.org/ns/1.0}placeName')
                    .find('{http://www.tei-c.org/ns/1.0}geogFeat').text)
        except:
            pass
        
        try:
            # Provenance
            provenance=(root.find('{http://www.tei-c.org/ns/1.0}teiHeader')
                   .find('{http://www.tei-c.org/ns/1.0}fileDesc')
                   .find('{http://www.tei-c.org/ns/1.0}sourceDesc')
                   .find('{http://www.tei-c.org/ns/1.0}msDesc')
                   .find('{http://www.tei-c.org/ns/1.0}history')
                   .find('{http://www.tei-c.org/ns/1.0}provenance')
                     .find('{http://www.tei-c.org/ns/1.0}placeName').text)
        except:
            pass
        
        try:
            # commentary
            commentary=(root.find('{http://www.tei-c.org/ns/1.0}text')
                   .find('{http://www.tei-c.org/ns/1.0}back')
                   .find('{http://www.tei-c.org/ns/1.0}div')[0].text)
            commentary=commentary.replace('\n              ','')
        except:
            pass
        
        dataf[ID]=[title,language,physical,religion,objec,support,unit,height,width,depth,condition,
                                 relief,column,line,unit_letter,small,large,old,early,region,city,geogname,
                                 geogfeature,provenance,commentary]

    
except:
        pass

df = pd.DataFrame(dataf)
df.to_csv('mger0007b.csv', index=False)
